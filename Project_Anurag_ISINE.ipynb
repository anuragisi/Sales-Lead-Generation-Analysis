# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragprasad95/Sales-Lead-Generation-Analysis/blob/main/Project_Anurag_ISINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Anurag Prasad
# # Indian Statistical Institute, North-East Centre

# %% [markdown]
# **Description**:
# The data used here, for Sales Qualified Leads Generated for FY 23-24
#
# **Sales Owner**: **29** Sales Team member responsible for conversion of lead to customer.
#
# **Entity Name**: Names of the **846** lead organization.
#
# **Current Stage**:
#
#             1. Customer - Identified **45** potential customers who may be interested in the product/service, but not yet engaged.
#             2. Proposal - Sending proposal to **64** potential customers.
#             3. Qualified Lead (QL) - **721** customers/leads qualified by Sales Team as a genuine.
#             4. Recently Qualified Lead (RQL) - **6** customers/leads recently qualified by Sales Team as a genuine.
#             5. Unqualified Lead (UQL) - **10** customers/leads not qualified by Sales Team as a genuine, may further require nurturing.
# **Status**:
#
#             1. Active - 36 customers/leads, 18 proposals, 248 QL, 6 RQL, 4 UQL
#             2. Free - 1 QL may have not been qualified further.
#             3. Lost - 9 customer, 38 proposals, 257 QL, 4 UQL have decided not to proceed with the purchase.
#             4. Nurture - 8  proposals, 215 QL, 2 UQL requires further nurturing to build their interest.
#
# **Prospect Creation Date**: Date of identification of the entities through different channels.
#
# **Lead Creation Date**: Date on which first positive response from that entities is received.
#
# **QL Creation  Date**: Date on which Sales Team marked them as a genuine customer/lead through defined process.
#
# **Lost Date**: Date on which the customer/lead did not convert.
#
# **Nurture Date**: Date on which customers/leads further nutured to build their intereest.
#
# **Won Date**: Date on which customer/lead convert into QL.
#
# **Channel**: 272 Emails, 278 LinkedIn, 113 Website, 74 Bidding, 40 Apollo.io, 19 Tender, 13 Paid, 3 Referral, 1 Cold call, 1 Job Board, 1 Nurturing, 31 No Channel Data Available.
#
# **Lead Score**: Score of lead is calculated through defined formula to understand business potential from the lead.Higher the lead score, better the lead.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Data

# %%
df = pd.read_excel('Lead Report-Assignment_data.xlsx')

# %% [markdown]
# View Dataframe

# %%
df
# Out:
#     Sales Owner  Entity Name Current Stage      Status  \
# 0            SN            1            QL      Active
# 1            AT            2            QL      Active
# 2            YS            3            QL      Active
# 3            NP            4            QL      Active
# 4            SC            5            QL        Free
# ..          ...          ...           ...         ...
# 841          Mn          842            QL        Lost
# 842          Ah          843            QL  Nurturable
# 843         SKV          844            QL        Lost
# 844          Mn          845            QL        Lost
# 845          Ah          846            QL  Nurturable
#
#           QL Creation  Date      Lead Creation Date  Prospect Creation Date  \
# 0   2024-01-17 05:30:00.000                     NaT                     NaT
# 1   2024-01-17 05:30:00.000                     NaT 2024-01-11 05:30:00.000
# 2   2024-01-17 05:30:00.000                     NaT 2024-01-16 05:30:00.000
# 3   2024-01-17 05:30:00.000                     NaT 2024-01-17 05:30:00.000
# 4   2024-01-16 05:30:00.000 2024-01-04 16:12:21.520 2021-01-13 22:44:10.266
# ..                      ...                     ...                     ...
# 841 2023-04-03 17:02:34.724 2023-04-03 17:02:34.724 2023-04-03 17:02:34.724
# 842 2023-04-03 16:59:40.732 2023-03-27 12:09:36.519 2021-08-31 21:05:26.201
# 843 2023-04-03 14:15:22.613 2023-04-03 14:15:22.613 2023-04-03 14:15:22.613
# 844 2023-04-03 12:05:57.680 2023-04-03 12:05:57.680 2020-07-02 14:18:08.766
# 845 2023-04-02 18:39:19.888 2023-03-22 12:23:19.014 2023-03-22 12:23:19.014
#
#                        Channel  Lead Score               Lost Date  \
# 0                        Email        0.75                     NaT
# 1                        Email        1.25                     NaT
# 2    No Channel Data Available        0.56                     NaT
# 3                      Website        0.25                     NaT
# 4                     LinkedIn        0.94                     NaT
# ..                         ...         ...                     ...
# 841                   LinkedIn        0.19 2023-05-09 05:30:00.000
# 842                     Tender        0.19 2023-04-24 19:43:04.762
# 843                    Website        0.47 2023-05-18 16:29:09.427
# 844                   LinkedIn        0.19 2023-05-09 05:30:00.000
# 845                     Tender        0.19 2023-04-24 22:20:23.719
#
#                 Nuture Date Won Date
# 0                       NaT      NaT
# 1                       NaT      NaT
# 2                       NaT      NaT
# 3                       NaT      NaT
# 4                       NaT      NaT
# ..                      ...      ...
# 841                     NaT      NaT
# 842 2023-04-24 19:43:04.762      NaT
# 843                     NaT      NaT
# 844                     NaT      NaT
# 845 2023-04-24 22:20:23.719      NaT
#
# [846 rows x 12 columns]

# %% [markdown]
# Total Rows & Columns

# %%
df.shape
# Out:
# (846, 12)

# %% [markdown]
# Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sales Owner             846 non-null    object
#  1   Entity Name             846 non-null    int64
#  2   Current Stage           846 non-null    object
#  3   Status                  846 non-null    object
#  4   QL Creation  Date       846 non-null    datetime64[ns]
#  5   Lead Creation Date      308 non-null    datetime64[ns]
#  6   Prospect Creation Date  803 non-null    datetime64[ns]
#  7   Channel                 846 non-null    object
#  8   Lead Score              846 non-null    float64
#  9   Lost Date               396 non-null    datetime64[ns]
#  10  Nuture Date             271 non-null    datetime64[ns]
#  11  Won Date                34 non-null     datetime64[ns]
# dtypes: datetime64[ns](6), float64(1), int64(1), object(4)
# memory usage: 79.4+ KB

# %% [markdown]
# **Data Quality Check**

# %% [markdown]
# Duplicate Values

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# Missing Values/Null Values

# %%
print(df.isnull().sum())
# Out:
# Sales Owner                 0
# Entity Name                 0
# Current Stage               0
# Status                      0
# QL Creation  Date           0
# Lead Creation Date        529
# Prospect Creation Date      0
# Channel                     0
# Lead Score                  0
# Lost Date                 418
# Nuture Date               539
# Won Date                  770
# dtype: int64

# %%
#Visualizing the missing values using heatmap
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Incomplete Records:

# %%
df = df.dropna(subset=['Prospect Creation Date'])
print(df.isnull().sum())
# Out:
# Sales Owner                 0
# Entity Name                 0
# Current Stage               0
# Status                      0
# QL Creation  Date           0
# Lead Creation Date        529
# Prospect Creation Date      0
# Channel                     0
# Lead Score                  0
# Lost Date                 418
# Nuture Date               539
# Won Date                  770
# dtype: int64

# %% [markdown]
# Incorrect Records:

# %% [markdown]
# Variable Information

# %%
#Columns
df.columns
# Out:
# Index(['Sales Owner', 'Entity Name', 'Current Stage', 'Status',
#        'QL Creation  Date', 'Lead Creation Date', 'Prospect Creation Date',
#        'Channel', 'Lead Score', 'Lost Date', 'Nuture Date', 'Won Date'],
#       dtype='object')

# %%
#Describe
df.describe(datetime_is_numeric=True)
# Out:
#        Entity Name              QL Creation  Date  \
# count   803.000000                            803
# mean    432.266501  2023-08-10 19:38:34.320195584
# min       2.000000     2023-04-02 18:39:19.888000
# 25%     229.500000  2023-06-06 13:20:06.802000128
# 50%     432.000000  2023-08-09 13:00:18.857999872
# 75%     635.500000  2023-09-29 19:34:22.998499840
# max     846.000000            2024-01-17 05:30:00
# std     238.435719                            NaN
#
#                   Lead Creation Date         Prospect Creation Date  \
# count                            274                            803
# mean   2023-06-21 11:26:42.886124288  2023-06-22 15:43:16.230263040
# min       2019-01-08 19:38:02.553000     2018-02-01 11:52:35.575000
# 25%    2023-05-12 12:03:05.568500224  2023-05-24 18:28:20.223000064
# 50%              2023-09-06 05:30:00  2023-08-24 16:10:33.436999936
# 75%              2023-11-07 05:30:00  2023-11-01 20:35:19.778000128
# max              2024-01-16 05:30:00            2024-01-17 05:30:00
# std                              NaN                            NaN
#
#        Lead Score                      Lost Date  \
# count  803.000000                            385
# mean     0.578593  2023-08-10 16:32:13.922215680
# min      0.130000     2019-01-23 13:51:50.942000
# 25%      0.380000  2023-06-22 21:27:43.708999936
# 50%      0.500000  2023-09-14 11:44:06.089999872
# 75%      0.750000     2023-11-01 16:38:28.476000
# max      1.750000            2024-01-16 05:30:00
# std      0.295055                            NaN
#
#                          Nuture Date                       Won Date
# count                            264                             33
# mean   2023-07-20 01:59:16.208643840  2023-08-13 09:23:10.972545536
# min       2019-10-16 19:20:33.475000     2023-04-17 17:10:56.640000
# 25%    2023-06-06 15:16:33.230749952  2023-07-10 13:59:19.844999936
# 50%    2023-08-21 12:51:54.257999872  2023-08-28 11:57:59.446000128
# 75%    2023-11-08 10:46:48.002249984     2023-09-25 14:16:21.496000
# max              2024-01-16 05:30:00     2023-11-06 18:11:03.677000
# std                              NaN                            NaN

# %%
#Check unique values for each variable
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  Sales Owner is 29 .
# No. of unique values in  Entity Name is 803 .
# No. of unique values in  Current Stage is 5 .
# No. of unique values in  Status is 4 .
# No. of unique values in  QL Creation  Date is 720 .
# No. of unique values in  Lead Creation Date is 228 .
# No. of unique values in  Prospect Creation Date is 684 .
# No. of unique values in  Channel is 12 .
# No. of unique values in  Lead Score is 23 .
# No. of unique values in  Lost Date is 316 .
# No. of unique values in  Nuture Date is 230 .
# No. of unique values in  Won Date is 33 .

# %% [markdown]
# **Analysis**

# %% [markdown]
# Lead Source Analysis

# %%
df['Channel'].value_counts()
# Out:
# LinkedIn                     261
# Email                        247
# Website                      112
# Bidding                       74
# Apollo.io                     40
# No Channel Data Available     31
# Tender                        19
# Paid                          13
# Referral                       3
# Nurturing                      1
# Cold Call                      1
# Job Board                      1
# Name: Channel, dtype: int64

# %%
# Plot a bar chart
plt.figure(figsize=(10, 6))
df['Channel'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Channels')
plt.xlabel('Channels')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# Comparing each Channels with mean Lead Score

# %%
# Count of unique channels
channel_counts = df['Channel'].value_counts().reset_index()
channel_counts.columns = ['Channel', 'Count']

# Median lead score for each channel
channel_lead = df.groupby('Channel')['Lead Score'].median().reset_index()
channel_lead.columns = ['Channel', 'Median Lead Score']

# Merge the two DataFrames on the 'Channel' column
channel_l = pd.merge(channel_counts, channel_lead, on='Channel')

channel_l
# Out:
#                       Channel  Count  Median Lead Score
# 0                    LinkedIn    261              0.470
# 1                       Email    247              0.500
# 2                     Website    112              0.470
# 3                     Bidding     74              0.380
# 4                   Apollo.io     40              0.595
# 5   No Channel Data Available     31              0.560
# 6                      Tender     19              0.750
# 7                        Paid     13              0.470
# 8                    Referral      3              1.250
# 9                   Nurturing      1              0.380
# 10                 Cold Call       1              0.840
# 11                  Job Board      1              0.750

# %%
# Plot a bar graph
plt.figure(figsize=(10, 6))
plt.bar(channel_lead['Channel'], channel_lead['Median Lead Score'], color='skyblue')
plt.xlabel('Channel')
plt.ylabel('Median Lead Score')
plt.title('Median Lead Score for Each Channel')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.grid(axis='y')

# %%
# Count of unique channels
channel_counts = df['Channel'].value_counts().reset_index()
channel_counts.columns = ['Channel', 'Count']

# Median lead score for each channel
channel_lead = df.groupby('Channel')['Lead Score'].median().reset_index()
channel_lead.columns = ['Channel', 'Median Lead Score']
channel_lead = channel_lead.sort_values(by='Median Lead Score')

# Merge the two DataFrames on the 'Channel' column
result_df = pd.merge(channel_counts, channel_lead, on='Channel')

# Display the combined DataFrame
print(result_df)
# Out:
#                       Channel  Count  Median Lead Score
# 0                    LinkedIn    261              0.470
# 1                       Email    247              0.500
# 2                     Website    112              0.470
# 3                     Bidding     74              0.380
# 4                   Apollo.io     40              0.595
# 5   No Channel Data Available     31              0.560
# 6                      Tender     19              0.750
# 7                        Paid     13              0.470
# 8                    Referral      3              1.250
# 9                   Nurturing      1              0.380
# 10                 Cold Call       1              0.840
# 11                  Job Board      1              0.750

# %%
# Larger plot size
fig, ax1 = plt.subplots(figsize=(25, 15))

# Bar plot for counts
color = 'tab:blue'
ax1.set_xlabel('Channel')
ax1.set_ylabel('Count', color=color)
ax1.bar(result_df['Channel'], result_df['Count'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Creating a second y-axis for the line plot
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Median Lead Score', color=color)
ax2.plot(result_df['Channel'], result_df['Median Lead Score'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)

# Title
plt.title('Comparison of Counts and Median Lead Score for Each Channel')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.show()

# %% [markdown]
# Number of entities handled by each Sales Owner (Sales Team)

# %%
lead_s = pd.DataFrame(df.groupby('Sales Owner')['Entity Name'].nunique())
lead_s = lead_s.sort_values(by='Entity Name', ascending=False).reset_index()
lead_s
# Out:
#    Sales Owner  Entity Name
# 0          SAM           73
# 1           NT           72
# 2           SN           71
# 3           SM           68
# 4           SC           67
# 5           BK           66
# 6           AT           50
# 7          SKV           44
# 8           RR           44
# 9           YS           43
# 10          Ah           38
# 11          AD           36
# 12          IT           26
# 13          KK           17
# 14         SAS           16
# 15          MS           14
# 16          GM           12
# 17         SDS            9
# 18          NP            8
# 19          Mn            7
# 20          AS            6
# 21          DP            4
# 22         ATS            4
# 23          BS            2
# 24         ARS            2
# 25          Rj            1
# 26         SHS            1
# 27          AM            1
# 28          AB            1

# %%
# Plot the data in a line chart
plt.figure(figsize=(10, 6))
plt.plot(lead_s['Sales Owner'], lead_s['Entity Name'], marker='o', linestyle='-', color='b')
plt.title('Number of Entities per Sales Owner')
plt.xlabel('Sales Owner')
plt.ylabel('Number of Entities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Current Stage Distribution

# %%
df['Current Stage'].value_counts()
# Out:
# QL          683
# Proposal     61
# Customer     44
# UQL          10
# RQL           5
# Name: Current Stage, dtype: int64

# %%
# Plot a horizontal bar chart
ax = df['Current Stage'].value_counts().plot(kind='barh', stacked=True, colormap='viridis', figsize=(10, 6))

# Add labels and title
ax.set_xlabel('Percentage')
ax.set_ylabel('Current Stage')
ax.set_title('Current Stage Distribution')

# Display the legend
ax.legend(title='Current Stage', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# Conversion Rates at different stages

# %% [markdown]
# 1.Stage = CUSTOMER

# %%
customer_data = df.loc[df['Current Stage'] == 'Customer', ['Current Stage', 'Won Date']]

# Display the result
print(customer_data.count())
# Out:
# Current Stage    44
# Won Date         32
# dtype: int64

# %%
customer_data['No Won Date'] = customer_data['Won Date'].isnull()
# Count the occurrences of non-null and null values in 'Won Date'
won_date_counts = customer_data['Won Date'].notnull().value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(won_date_counts, labels=['Customer', 'Lost'], autopct='%1.1f%%', colors=['lightblue', 'lightcoral'])
plt.title('Distribution of Won Date for Customer Stage=Customer')
plt.show()

# %% [markdown]
# 2.Stage = Proposal

# %%
customer_data1 = df.loc[df['Current Stage'] == 'Proposal', ['Current Stage', 'Won Date']]

# Display the result
print(customer_data1.count())
# Out:
# Current Stage    61
# Won Date          1
# dtype: int64

# %%
# Count the occurrences of non-null and null values in 'Won Date'
won_date_count = customer_data1['Won Date'].notnull().value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(won_date_count, labels=['Lost', 'Customer'], autopct='%1.1f%%', colors=['lightblue','darkblue'])
plt.title('Distribution of Won Date for Customer Stage=Proposal')
plt.show()

# %% [markdown]
# 3.Stage = QL

# %%
customer_data2 = df.loc[df['Current Stage'] == 'QL', ['Current Stage', 'Won Date']]

# Display the result
print(customer_data2.count())
# Out:
# Current Stage    683
# Won Date           0
# dtype: int64

# %% [markdown]
# 4.Stage = RQL

# %%
customer_data3 = df.loc[df['Current Stage'] == 'RQL', ['Current Stage', 'Won Date']]

# Display the result
print(customer_data3.count())
# Out:
# Current Stage    5
# Won Date         0
# dtype: int64

# %% [markdown]
# 5.Stage = UQL

# %%
customer_data4 = df.loc[df['Current Stage'] == 'UQL', ['Current Stage', 'Won Date']]

# Display the result
print(customer_data4.count())
# Out:
# Current Stage    10
# Won Date          0
# dtype: int64

# %% [markdown]
# Lead Response Time

# %% [markdown]
# We are finding the difference between QL Creation Date and Prospect Creation Date.

# %%
# Select only the relevant columns
df['Date Difference'] = df['QL Creation  Date'] - df['Prospect Creation Date']
df_sorted = df.sort_values(by='Date Difference')
#df_sorted

# %%
# Select only the relevant columns
result_df = df_sorted[['Date Difference','Won Date']]
#result_df

# %%
# Select only the relevant columns
result_df = df_sorted[['Date Difference','Won Date']]
result_df.count()
# Out:
# Date Difference    803
# Won Date            33
# dtype: int64

# %% [markdown]
# Assuming here that,
#
#
# 1.   QL Creation Date on/after Prospect Creation Date, then its NEW entity into the database.
# 2.   QL Creation Date before Prospect Creation Date, then its OLD entity from the database.

# %%
# Filter based on Date Difference < 0 and count not null Won Date
negative_difference = df[df['Date Difference'] < pd.Timedelta(0)]
count_not_null_won_date_negative = negative_difference['Won Date'].count()

# Filter based on Date Difference = 0 and count not null Won Date
equal_difference = df[df['Date Difference'] == pd.Timedelta(0)]
count_not_null_won_date_equal = equal_difference['Won Date'].count()

# Filter based on Date Difference > 0 and count not null Won Date
non_negative_difference = df[df['Date Difference'] > pd.Timedelta(0)]
count_not_null_won_date_non_negative = non_negative_difference['Won Date'].count()

# Display the results
print(f"{count_not_null_won_date_negative} number of leads won for OLD Entities/Prospects (where Date Difference < 0)")
print(f"{count_not_null_won_date_equal} number of leads Won for New Entities/Prospects contacted on same day (where Date Difference = 0)")
print(f"{count_not_null_won_date_non_negative} number of leads Won for New Entities/Prospects (where Date Difference > 0)")
# Out:
# 6 number of leads won for OLD Entities/Prospects (where Date Difference < 0)
# 11 number of leads Won for New Entities/Prospects contacted on same day (where Date Difference = 0)
# 16 number of leads Won for New Entities/Prospects (where Date Difference > 0)

# %%
# Circular area plot
categories = ['OLD Entities/Prospects', 'New Entities/Prospects contacted on same day', 'New Entities/Prospects']
counts = [count_not_null_won_date_negative, count_not_null_won_date_equal, count_not_null_won_date_non_negative]

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))

wedges, texts, autotexts = ax.pie(counts, autopct='%1.1f%%', textprops=dict(color="w"))

ax.legend(wedges, categories, title="Categories", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Count of Leads Won for Prospects/Entites categories")

# Display the plot
plt.show()

# %% [markdown]
# For past Nurture entites, number of leads won

# %%
# Count total Won Date when Nurture Date is not null
count_won_date_not_null_nurture = df[df['Nuture Date'].notnull()]['Won Date'].count()

# Display the result
print("Total Leads Won Date when Nurture Date is not null:", count_won_date_not_null_nurture)
# Out:
# Total Leads Won Date when Nurture Date is not null: 4

# %% [markdown]
# Lead Scoring

# %% [markdown]
# ### Actionable Insights found

# %% [markdown]
# 1. Top 3 channels from where the 77.21% of the total entities are coming are LinkedIn, Email, Website.
# 2. Top 3 channels for generating Quality Leads are Referral, Cold call, Job Board.
# 3. 73.3% of leads converted from the entities having stage = Customers.
# 4. 1.6% of leads convereted from entities having stage = Proposals.
# 5. There are negligible changes of converting leads when entities having stage = QL, RQL, UQL.
# 6. 48.5% leads converting from new entities/prospects.
# 7. 33.33% leads converting from entities/prospects which are contacted on same day through various channels.
# 8. 18.20% leads converting from old entities/prospects.
# 9. 12.12% leads converted from nurturing entities.
# 10. Restructing Lead Score formula because, leads converted when lead scroe<1 is 32, else its 1 only.
# 11. 17 Sales owner had got most entities/propects but rest have few below 10 in numbers.
